# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def parse_reviews_from_html(html_content):
    # Se obtiene el codigo html y se accede a la parte de las reviews
    soup = BeautifulSoup(html_content, 'html.parser')
    review_elements = soup.find_all('div', class_='review-element')
    reviews_data = []
    
    for review in review_elements:
        # Se extrae el texto con una comprobacion
        review_text_element = review.find('div', class_='text')
        review_text = review_text_element.text.strip() if review_text_element else "No text found"

        # Se comprueba si la etiqueta de recomendación existe
        tags_div = review.find('div', class_='tags')
        
        if tags_div:
            # Se obtiene la polaridad de la reseña
            recommendation_status = tags_div.text.strip()
            
            # Se comprueba si la polaridad es una de las que queremos
            if recommendation_status in ["Recommended", "Not Recommended", "Mixed Feelings"]:
                # Se añade tanto el texto como la marca de polaridad
                reviews_data.append({
                    'review_text': review_text,
                    'polarity': recommendation_status
                })
            
    return reviews_data

def scrape_anime_reviews(anime_id, anime_title, max_reviews=100):  
    # Se inicializa la lista de reseñas y el parámetro de orden
    valid_reviews = []
    sort_by = 'suggested'
    base_url = f"https://myanimelist.net/anime/{anime_id}/{anime_title}/reviews?sort={sort_by}"
    print(f"Scrapeando reseñas desde: {base_url}")

    # Se usa un 'set' para guardar los textos que ya hemos visto
    seen_review_texts = set()

    # Se intenta obtener la primera página de reseñas
    try:
        response = requests.get(base_url, headers={'User-Agent': 'Mozilla/5.0'})
        response.raise_for_status()
        
        initial_reviews = parse_reviews_from_html(response.text)
        
        # Se añaden las reseñas de una en una, comprobando duplicados
        for review in initial_reviews:
            if review['review_text'] not in seen_review_texts:
                valid_reviews.append(review)
                seen_review_texts.add(review['review_text'])
        
    except requests.exceptions.RequestException as e:
        print(f"Error en la página inicial de reseñas: {e}")
        return [] 

    # Se prepara el contador para la paginación (Página 2 en adelante)
    page_number = 2
    
    while len(valid_reviews) < max_reviews:
        
        time.sleep(2) 
        load_more_url = f"{base_url}&p={page_number}"
        
        try:
            response = requests.get(load_more_url, headers={'User-Agent': 'Mozilla/5.0'})
            response.raise_for_status()
            
            additional_reviews = parse_reviews_from_html(response.text)
            
            # Si no hay más reseñas, se rompe el bucle
            if not additional_reviews:
                print("No hay más reseñas disponibles (filtro o fin real).")
                break 
            
            # Se comprueba si el texto de la reseña NO está en el set previamente creado
            new_reviews_found_count = 0
            for review in additional_reviews:
                if review['review_text'] not in seen_review_texts:
                    valid_reviews.append(review)
                    seen_review_texts.add(review['review_text'])
                    new_reviews_found_count += 1

            # Se comprueba que la pagina no sea una pagina repetida
            if new_reviews_found_count == 0 and additional_reviews:
                print("Página duplicada detectada. Deteniendo búsqueda.")
                break 

            page_number += 1
            
        except requests.exceptions.RequestException as e:
            print(f"Error en página {page_number}: {e}. Deteniendo.")
            break 
            
    # Se devuelve la lista final, cortada al máximo
    return valid_reviews[:max_reviews]

def get_top_anime_list(limit=100):
    # Se inicializan las variables para guardar la lista y manejar la paginación
    anime_list = []
    start_rank = 0
    print("Obteniendo la lista del top 100 de animes...")
    
    # Se inicia el bucle para scrapear páginas hasta alcanzar el límite
    while len(anime_list) < limit:
        
        # Se construye la URL correcta, manejando el caso especial de la página 1
        if start_rank == 0:
            url = "https://myanimelist.net/topanime.php"
        else:
            url = f"https://myanimelist.net/topanime.php?limit={start_rank}"

        print(f"Accediendo a: {url}")
        
        # Se intenta obtener la página de ranking
        try:
            response = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})
            response.raise_for_status()
        except requests.exceptions.RequestException as e:
            print(f"Error al acceder a la página de ranking: {e}")
            break

        # Se parsea el HTML y se buscan todas las filas de la tabla
        soup = BeautifulSoup(response.text, 'html.parser')
        ranking_rows = soup.find_all('tr', class_='ranking-list')
        
        # Se itera sobre cada fila (cada anime) encontrada en la página
        for row in ranking_rows:
            # Se busca el enlace principal que contiene la URL
            link_element = row.find('a', class_='hoverinfo_trigger')
            
            # Se comprueba si el enlace existe y si aún no hemos llegado al límite
            if link_element and len(anime_list) < limit:
                url_anime = link_element['href']
                
                # Se intenta extraer el ID y el 'slug' del título desde la URL
                try:
                    parts = url_anime.split('/')
                    anime_id = int(parts[4])
                    anime_title_slug = parts[5]
                    anime_list.append({'id': anime_id, 'title_slug': anime_title_slug})
                except (IndexError, ValueError):
                    continue
        
        # Se prepara para la siguiente página
        start_rank += 50
        time.sleep(1) # Pausa entre páginas del ranking

    print(f"Se encontraron {len(anime_list)} animes en el top.")
    return anime_list


if __name__ == "__main__":
    # Se definen las columnas que queremos al final
    reviews_complete_df = pd.DataFrame()
    
    # Se define el límite total de reseñas que queremos
    LIMITE_TOTAL = 10000
    
    # Se obtiene la lista de los 150 peimweoa animes para tener margen
    top_animes = get_top_anime_list(limit=150) 
    
    print(f"Iniciando scrapeo. Objetivo: {LIMITE_TOTAL} reseñas.")
    
    # Se comprueba si la lista de animes se obtuvo correctamente
    if not top_animes:
        print("No se pudo obtener la lista de animes. Saliendo del programa.")
    else:
        # Se itera sobre cada anime de la lista para procesarlo
        for i, anime in enumerate(top_animes):
            
            print(f"Procesando Anime {i+1}/{len(top_animes)}: {anime['title_slug']}")
            
            # Se obtienen las reseñas para el anime actual
            reseñas = scrape_anime_reviews(anime['id'], anime['title_slug'], max_reviews=100)
            
            # Se comprueba si se obtuvieron reseñas
            if reseñas:
                # Se convierten las reseñas (lista) a un DataFrame temporal
                temp_df = pd.DataFrame(reseñas)
                
                # Se añade la columna 'tittle' usando el 'slug' del anime
                temp_df['tittle'] = anime['title_slug']
                
                # Se añade este DataFrame temporal al DataFrame global
                reviews_complete_df = pd.concat([reviews_complete_df, temp_df], ignore_index=True)
                
                print(f"Añadidas {len(reseñas)} reseñas. Total actual: {len(reviews_complete_df)}")
            else:
                print(f"No se encontraron reseñas para {anime['title_slug']}")
            
            # Se comprueba si hemos alcanzado el límite total
            if len(reviews_complete_df) >= LIMITE_TOTAL:
                print(f"Límite de {LIMITE_TOTAL} reseñas alcanzado.")
                break 
            
            # Se aplica una pausa de cortesía entre cada anime
            time.sleep(3)
    
    # Se muestra la cantidad de reseñas guardadas totales.
    print(f"Guardando {len(reviews_complete_df)} reseñas totales en 'reviews_complete.csv'.")
    
    # Se reordenan las columnas para dejar la columna objetivo la última
    reviews_complete_df = reviews_complete_df[['tittle', 'review_text', 'polarity']]
    
    # Se guarda el DataFrame en un único archivo CSV
    reviews_complete_df.to_csv("reviews_complete.csv", index=False, encoding='utf-8-sig')
    
    print("Proceso de scraping masivo completado")
# Out:
# Obteniendo la lista del top 100 de animes...
# Accediendo a: https://myanimelist.net/topanime.php
# Accediendo a: https://myanimelist.net/topanime.php?limit=50
# Accediendo a: https://myanimelist.net/topanime.php?limit=100
# Se encontraron 150 animes en el top.
# Iniciando scrapeo. Objetivo: 10000 reseñas.
# Procesando Anime 1/150: Sousou_no_Frieren
# Scrapeando reseñas desde: https://myanimelist.net/anime/52991/Sousou_no_Frieren/reviews?sort=suggested
# No hay más reseñas disponibles (filtro o fin real).
# Añadidas 13 reseñas. Total actual: 13
# Procesando Anime 2/150: Chainsaw_Man_Movie__Reze-hen
# Scrapeando reseñas desde: https://myanimelist.net/anime/57555/Chainsaw_Man_Movie__Reze-hen/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 113
# Procesando Anime 3/150: Fullmetal_Alchemist__Brotherhood
# Scrapeando reseñas desde: https://myanimelist.net/anime/5114/Fullmetal_Alchemist__Brotherhood/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 213
# Procesando Anime 4/150: Steins_Gate
# Scrapeando reseñas desde: https://myanimelist.net/anime/9253/Steins_Gate/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 313
# Procesando Anime 5/150: Shingeki_no_Kyojin_Season_3_Part_2
# Scrapeando reseñas desde: https://myanimelist.net/anime/38524/Shingeki_no_Kyojin_Season_3_Part_2/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 413
# Procesando Anime 6/150: Gintama__The_Final
# Scrapeando reseñas desde: https://myanimelist.net/anime/39486/Gintama__The_Final/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 76 reseñas. Total actual: 489
# Procesando Anime 7/150: Gintama°
# Scrapeando reseñas desde: https://myanimelist.net/anime/28977/Gintama°/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 78 reseñas. Total actual: 567
# Procesando Anime 8/150: Hunter_x_Hunter_2011
# Scrapeando reseñas desde: https://myanimelist.net/anime/11061/Hunter_x_Hunter_2011/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 667
# Procesando Anime 9/150: One_Piece_Fan_Letter
# Scrapeando reseñas desde: https://myanimelist.net/anime/60022/One_Piece_Fan_Letter/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 40 reseñas. Total actual: 707
# Procesando Anime 10/150: Ginga_Eiyuu_Densetsu
# Scrapeando reseñas desde: https://myanimelist.net/anime/820/Ginga_Eiyuu_Densetsu/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 807
# Procesando Anime 11/150: Gintama
# Scrapeando reseñas desde: https://myanimelist.net/anime/9969/Gintama/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 34 reseñas. Total actual: 841
# Procesando Anime 12/150: Gintama__Enchousen
# Scrapeando reseñas desde: https://myanimelist.net/anime/15417/Gintama__Enchousen/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 23 reseñas. Total actual: 864
# Procesando Anime 13/150: Kingdom_6th_Season
# Scrapeando reseñas desde: https://myanimelist.net/anime/61517/Kingdom_6th_Season/reviews?sort=suggested
# No hay más reseñas disponibles (filtro o fin real).
# No se encontraron reseñas para Kingdom_6th_Season
# Procesando Anime 14/150: Bleach__Sennen_Kessen-hen
# Scrapeando reseñas desde: https://myanimelist.net/anime/41467/Bleach__Sennen_Kessen-hen/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 54 reseñas. Total actual: 918
# Procesando Anime 15/150: Gintama
# Scrapeando reseñas desde: https://myanimelist.net/anime/34096/Gintama/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 21 reseñas. Total actual: 939
# Procesando Anime 16/150: Kaguya-sama_wa_Kokurasetai__Ultra_Romantic
# Scrapeando reseñas desde: https://myanimelist.net/anime/43608/Kaguya-sama_wa_Kokurasetai__Ultra_Romantic/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 1039
# Procesando Anime 17/150: Fruits_Basket__The_Final
# Scrapeando reseñas desde: https://myanimelist.net/anime/42938/Fruits_Basket__The_Final/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 1139
# Procesando Anime 18/150: Clannad__After_Story
# Scrapeando reseñas desde: https://myanimelist.net/anime/4181/Clannad__After_Story/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 1239
# Procesando Anime 19/150: Gintama
# Scrapeando reseñas desde: https://myanimelist.net/anime/918/Gintama/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 1339
# Procesando Anime 20/150: Koe_no_Katachi
# Scrapeando reseñas desde: https://myanimelist.net/anime/28851/Koe_no_Katachi/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 1439
# Procesando Anime 21/150: Kusuriya_no_Hitorigoto_2nd_Season
# Scrapeando reseñas desde: https://myanimelist.net/anime/58514/Kusuriya_no_Hitorigoto_2nd_Season/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 24 reseñas. Total actual: 1463
# Procesando Anime 22/150: Code_Geass__Hangyaku_no_Lelouch_R2
# Scrapeando reseñas desde: https://myanimelist.net/anime/2904/Code_Geass__Hangyaku_no_Lelouch_R2/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 1563
# Procesando Anime 23/150: 3-gatsu_no_Lion_2nd_Season
# Scrapeando reseñas desde: https://myanimelist.net/anime/35180/3-gatsu_no_Lion_2nd_Season/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 1663
# Procesando Anime 24/150: Gintama_Movie_2__Kanketsu-hen_-_Yorozuya_yo_Eien_Nare
# Scrapeando reseñas desde: https://myanimelist.net/anime/15335/Gintama_Movie_2__Kanketsu-hen_-_Yorozuya_yo_Eien_Nare/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 42 reseñas. Total actual: 1705
# Procesando Anime 25/150: Monster
# Scrapeando reseñas desde: https://myanimelist.net/anime/19/Monster/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 1805
# Procesando Anime 26/150: Gintama_Shirogane_no_Tamashii-hen_-_Kouhan-sen
# Scrapeando reseñas desde: https://myanimelist.net/anime/37491/Gintama_Shirogane_no_Tamashii-hen_-_Kouhan-sen/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 18 reseñas. Total actual: 1823
# Procesando Anime 27/150: Kusuriya_no_Hitorigoto
# Scrapeando reseñas desde: https://myanimelist.net/anime/54492/Kusuriya_no_Hitorigoto/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 1923
# Procesando Anime 28/150: Owarimonogatari_2nd_Season
# Scrapeando reseñas desde: https://myanimelist.net/anime/35247/Owarimonogatari_2nd_Season/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 50 reseñas. Total actual: 1973
# Procesando Anime 29/150: Shingeki_no_Kyojin__The_Final_Season_-_Kanketsu-hen
# Scrapeando reseñas desde: https://myanimelist.net/anime/51535/Shingeki_no_Kyojin__The_Final_Season_-_Kanketsu-hen/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 2073
# Procesando Anime 30/150: Shingeki_no_Kyojin_Movie__Kanketsu-hen_-_The_Last_Attack
# Scrapeando reseñas desde: https://myanimelist.net/anime/59571/Shingeki_no_Kyojin_Movie__Kanketsu-hen_-_The_Last_Attack/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 11 reseñas. Total actual: 2084
# Procesando Anime 31/150: Violet_Evergarden_Movie
# Scrapeando reseñas desde: https://myanimelist.net/anime/37987/Violet_Evergarden_Movie/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 2184
# Procesando Anime 32/150: Kimi_no_Na_wa
# Scrapeando reseñas desde: https://myanimelist.net/anime/32281/Kimi_no_Na_wa/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 2284
# Procesando Anime 33/150: Kingdom_3rd_Season
# Scrapeando reseñas desde: https://myanimelist.net/anime/40682/Kingdom_3rd_Season/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 10 reseñas. Total actual: 2294
# Procesando Anime 34/150: Vinland_Saga_Season_2
# Scrapeando reseñas desde: https://myanimelist.net/anime/49387/Vinland_Saga_Season_2/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 2394
# Procesando Anime 35/150: Gintama_Shirogane_no_Tamashii-hen
# Scrapeando reseñas desde: https://myanimelist.net/anime/36838/Gintama_Shirogane_no_Tamashii-hen/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 19 reseñas. Total actual: 2413
# Procesando Anime 36/150: Takopii_no_Genzai
# Scrapeando reseñas desde: https://myanimelist.net/anime/60489/Takopii_no_Genzai/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 2513
# Procesando Anime 37/150: Boku_no_Hero_Academia__Final_Season
# Scrapeando reseñas desde: https://myanimelist.net/anime/60098/Boku_no_Hero_Academia__Final_Season/reviews?sort=suggested
# No hay más reseñas disponibles (filtro o fin real).
# No se encontraron reseñas para Boku_no_Hero_Academia__Final_Season
# Procesando Anime 38/150: Hajime_no_Ippo
# Scrapeando reseñas desde: https://myanimelist.net/anime/263/Hajime_no_Ippo/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 2613
# Procesando Anime 39/150: Shingeki_no_Kyojin__The_Final_Season
# Scrapeando reseñas desde: https://myanimelist.net/anime/40028/Shingeki_no_Kyojin__The_Final_Season/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 2713
# Procesando Anime 40/150: Kizumonogatari_III__Reiketsu-hen
# Scrapeando reseñas desde: https://myanimelist.net/anime/31758/Kizumonogatari_III__Reiketsu-hen/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 45 reseñas. Total actual: 2758
# Procesando Anime 41/150: Mob_Psycho_100_II
# Scrapeando reseñas desde: https://myanimelist.net/anime/37510/Mob_Psycho_100_II/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 2858
# Procesando Anime 42/150: Ashita_no_Joe_2
# Scrapeando reseñas desde: https://myanimelist.net/anime/2921/Ashita_no_Joe_2/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 25 reseñas. Total actual: 2883
# Procesando Anime 43/150: Haikyuu_Karasuno_Koukou_vs_Shiratorizawa_Gakuen_Koukou
# Scrapeando reseñas desde: https://myanimelist.net/anime/32935/Haikyuu_Karasuno_Koukou_vs_Shiratorizawa_Gakuen_Koukou/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 78 reseñas. Total actual: 2961
# Procesando Anime 44/150: Sen_to_Chihiro_no_Kamikakushi
# Scrapeando reseñas desde: https://myanimelist.net/anime/199/Sen_to_Chihiro_no_Kamikakushi/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 3061
# Procesando Anime 45/150: Shingeki_no_Kyojin__The_Final_Season_Part_2
# Scrapeando reseñas desde: https://myanimelist.net/anime/48583/Shingeki_no_Kyojin__The_Final_Season_Part_2/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 3161
# Procesando Anime 46/150: Vinland_Saga
# Scrapeando reseñas desde: https://myanimelist.net/anime/37521/Vinland_Saga/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 3261
# Procesando Anime 47/150: Monogatari_Series__Second_Season
# Scrapeando reseñas desde: https://myanimelist.net/anime/17074/Monogatari_Series__Second_Season/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 84 reseñas. Total actual: 3345
# Procesando Anime 48/150: Cowboy_Bebop
# Scrapeando reseñas desde: https://myanimelist.net/anime/1/Cowboy_Bebop/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 3445
# Procesando Anime 49/150: Bocchi_the_Rock
# Scrapeando reseñas desde: https://myanimelist.net/anime/47917/Bocchi_the_Rock/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 3545
# Procesando Anime 50/150: Kingdom_4th_Season
# Scrapeando reseñas desde: https://myanimelist.net/anime/50160/Kingdom_4th_Season/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 3 reseñas. Total actual: 3548
# Procesando Anime 51/150: One_Piece
# Scrapeando reseñas desde: https://myanimelist.net/anime/21/One_Piece/reviews?sort=suggested
# No hay más reseñas disponibles (filtro o fin real).
# No se encontraron reseñas para One_Piece
# Procesando Anime 52/150: Jujutsu_Kaisen_2nd_Season
# Scrapeando reseñas desde: https://myanimelist.net/anime/51009/Jujutsu_Kaisen_2nd_Season/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 97 reseñas. Total actual: 3645
# Procesando Anime 53/150: Kaguya-sama_wa_Kokurasetai__First_Kiss_wa_Owaranai
# Scrapeando reseñas desde: https://myanimelist.net/anime/52198/Kaguya-sama_wa_Kokurasetai__First_Kiss_wa_Owaranai/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 47 reseñas. Total actual: 3692
# Procesando Anime 54/150: Kingdom_5th_Season
# Scrapeando reseñas desde: https://myanimelist.net/anime/53223/Kingdom_5th_Season/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 4 reseñas. Total actual: 3696
# Procesando Anime 55/150: Mushishi_Zoku_Shou_2nd_Season
# Scrapeando reseñas desde: https://myanimelist.net/anime/24701/Mushishi_Zoku_Shou_2nd_Season/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 17 reseñas. Total actual: 3713
# Procesando Anime 56/150: Shiguang_Dailiren
# Scrapeando reseñas desde: https://myanimelist.net/anime/44074/Shiguang_Dailiren/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 3813
# Procesando Anime 57/150: Tu_Bian_Yingxiong_X
# Scrapeando reseñas desde: https://myanimelist.net/anime/53447/Tu_Bian_Yingxiong_X/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 56 reseñas. Total actual: 3869
# Procesando Anime 58/150: 86_Part_2
# Scrapeando reseñas desde: https://myanimelist.net/anime/48569/86_Part_2/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 3969
# Procesando Anime 59/150: Boku_no_Kokoro_no_Yabai_Yatsu_2nd_Season
# Scrapeando reseñas desde: https://myanimelist.net/anime/55690/Boku_no_Kokoro_no_Yabai_Yatsu_2nd_Season/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 85 reseñas. Total actual: 4054
# Procesando Anime 60/150: Hibike_Euphonium_3
# Scrapeando reseñas desde: https://myanimelist.net/anime/39894/Hibike_Euphonium_3/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 36 reseñas. Total actual: 4090
# Procesando Anime 61/150: Code_Geass__Hangyaku_no_Lelouch
# Scrapeando reseñas desde: https://myanimelist.net/anime/1575/Code_Geass__Hangyaku_no_Lelouch/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 4190
# Procesando Anime 62/150: Kimetsu_no_Yaiba_Movie_1__Mugenjou-hen_-_Akaza_Sairai
# Scrapeando reseñas desde: https://myanimelist.net/anime/59192/Kimetsu_no_Yaiba_Movie_1__Mugenjou-hen_-_Akaza_Sairai/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 43 reseñas. Total actual: 4233
# Procesando Anime 63/150: Kimetsu_no_Yaiba__Yuukaku-hen
# Scrapeando reseñas desde: https://myanimelist.net/anime/47778/Kimetsu_no_Yaiba__Yuukaku-hen/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 4333
# Procesando Anime 64/150: Mob_Psycho_100_III
# Scrapeando reseñas desde: https://myanimelist.net/anime/50172/Mob_Psycho_100_III/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 79 reseñas. Total actual: 4412
# Procesando Anime 65/150: The_First_Slam_Dunk
# Scrapeando reseñas desde: https://myanimelist.net/anime/45649/The_First_Slam_Dunk/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 32 reseñas. Total actual: 4444
# Procesando Anime 66/150: Shouwa_Genroku_Rakugo_Shinjuu__Sukeroku_Futatabi-hen
# Scrapeando reseñas desde: https://myanimelist.net/anime/33095/Shouwa_Genroku_Rakugo_Shinjuu__Sukeroku_Futatabi-hen/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 50 reseñas. Total actual: 4494
# Procesando Anime 67/150: Bleach__Sennen_Kessen-hen_-_Ketsubetsu-tan
# Scrapeando reseñas desde: https://myanimelist.net/anime/53998/Bleach__Sennen_Kessen-hen_-_Ketsubetsu-tan/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 15 reseñas. Total actual: 4509
# Procesando Anime 68/150: Chi_Chikyuu_no_Undou_ni_Tsuite
# Scrapeando reseñas desde: https://myanimelist.net/anime/52215/Chi_Chikyuu_no_Undou_ni_Tsuite/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 90 reseñas. Total actual: 4599
# Procesando Anime 69/150: Rurouni_Kenshin__Meiji_Kenkaku_Romantan_-_Tsuioku-hen
# Scrapeando reseñas desde: https://myanimelist.net/anime/44/Rurouni_Kenshin__Meiji_Kenkaku_Romantan_-_Tsuioku-hen/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 72 reseñas. Total actual: 4671
# Procesando Anime 70/150: Violet_Evergarden
# Scrapeando reseñas desde: https://myanimelist.net/anime/33352/Violet_Evergarden/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 4771
# Procesando Anime 71/150: Great_Teacher_Onizuka
# Scrapeando reseñas desde: https://myanimelist.net/anime/245/Great_Teacher_Onizuka/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 4871
# Procesando Anime 72/150: Mo_Dao_Zu_Shi__Wanjie_Pian
# Scrapeando reseñas desde: https://myanimelist.net/anime/40434/Mo_Dao_Zu_Shi__Wanjie_Pian/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 10 reseñas. Total actual: 4881
# Procesando Anime 73/150: Mushishi_Zoku_Shou
# Scrapeando reseñas desde: https://myanimelist.net/anime/21939/Mushishi_Zoku_Shou/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 28 reseñas. Total actual: 4909
# Procesando Anime 74/150: Mononoke_Hime
# Scrapeando reseñas desde: https://myanimelist.net/anime/164/Mononoke_Hime/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 5009
# Procesando Anime 75/150: Bleach__Sennen_Kessen-hen_-_Soukoku-tan
# Scrapeando reseñas desde: https://myanimelist.net/anime/56784/Bleach__Sennen_Kessen-hen_-_Soukoku-tan/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 17 reseñas. Total actual: 5026
# Procesando Anime 76/150: Hajime_no_Ippo__New_Challenger
# Scrapeando reseñas desde: https://myanimelist.net/anime/5258/Hajime_no_Ippo__New_Challenger/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 17 reseñas. Total actual: 5043
# Procesando Anime 77/150: Howl_no_Ugoku_Shiro
# Scrapeando reseñas desde: https://myanimelist.net/anime/431/Howl_no_Ugoku_Shiro/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 5143
# Procesando Anime 78/150: Kaoru_Hana_wa_Rin_to_Saku
# Scrapeando reseñas desde: https://myanimelist.net/anime/59845/Kaoru_Hana_wa_Rin_to_Saku/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 64 reseñas. Total actual: 5207
# Procesando Anime 79/150: Monogatari_Series__Off___Monster_Season
# Scrapeando reseñas desde: https://myanimelist.net/anime/57864/Monogatari_Series__Off___Monster_Season/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 9 reseñas. Total actual: 5216
# Procesando Anime 80/150: Mushishi
# Scrapeando reseñas desde: https://myanimelist.net/anime/457/Mushishi/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 5316
# Procesando Anime 81/150: Tian_Guan_Cifu_Er
# Scrapeando reseñas desde: https://myanimelist.net/anime/50399/Tian_Guan_Cifu_Er/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 4 reseñas. Total actual: 5320
# Procesando Anime 82/150: Guimi_Zhi_Zhu__Xiaochou_Pian
# Scrapeando reseñas desde: https://myanimelist.net/anime/49818/Guimi_Zhi_Zhu__Xiaochou_Pian/reviews?sort=suggested
# No hay más reseñas disponibles (filtro o fin real).
# Añadidas 42 reseñas. Total actual: 5362
# Procesando Anime 83/150: Fate_stay_night_Movie__Heavens_Feel_-_III_Spring_Song
# Scrapeando reseñas desde: https://myanimelist.net/anime/33050/Fate_stay_night_Movie__Heavens_Feel_-_III_Spring_Song/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 94 reseñas. Total actual: 5456
# Procesando Anime 84/150: Shigatsu_wa_Kimi_no_Uso
# Scrapeando reseñas desde: https://myanimelist.net/anime/23273/Shigatsu_wa_Kimi_no_Uso/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 5556
# Procesando Anime 85/150: Shiguang_Dailiren_II
# Scrapeando reseñas desde: https://myanimelist.net/anime/49413/Shiguang_Dailiren_II/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 34 reseñas. Total actual: 5590
# Procesando Anime 86/150: Shingeki_no_Kyojin_Season_3
# Scrapeando reseñas desde: https://myanimelist.net/anime/35760/Shingeki_no_Kyojin_Season_3/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 97 reseñas. Total actual: 5687
# Procesando Anime 87/150: Tengen_Toppa_Gurren_Lagann
# Scrapeando reseñas desde: https://myanimelist.net/anime/2001/Tengen_Toppa_Gurren_Lagann/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 5787
# Procesando Anime 88/150: Uma_Musume__Pretty_Derby_-_Shin_Jidai_no_Tobira
# Scrapeando reseñas desde: https://myanimelist.net/anime/57647/Uma_Musume__Pretty_Derby_-_Shin_Jidai_no_Tobira/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 23 reseñas. Total actual: 5810
# Procesando Anime 89/150: Look_Back
# Scrapeando reseñas desde: https://myanimelist.net/anime/58125/Look_Back/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 79 reseñas. Total actual: 5889
# Procesando Anime 90/150: Made_in_Abyss
# Scrapeando reseñas desde: https://myanimelist.net/anime/34599/Made_in_Abyss/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 5989
# Procesando Anime 91/150: Natsume_Yuujinchou_Shi
# Scrapeando reseñas desde: https://myanimelist.net/anime/11665/Natsume_Yuujinchou_Shi/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 17 reseñas. Total actual: 6006
# Procesando Anime 92/150: Odd_Taxi
# Scrapeando reseñas desde: https://myanimelist.net/anime/46102/Odd_Taxi/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 6106
# Procesando Anime 93/150: Ping_Pong_the_Animation
# Scrapeando reseñas desde: https://myanimelist.net/anime/22135/Ping_Pong_the_Animation/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 6206
# Procesando Anime 94/150: Kaguya-sama_wa_Kokurasetai_Tensai-tachi_no_Renai_Zunousen
# Scrapeando reseñas desde: https://myanimelist.net/anime/40591/Kaguya-sama_wa_Kokurasetai_Tensai-tachi_no_Renai_Zunousen/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 6306
# Procesando Anime 95/150: Mushoku_Tensei__Isekai_Ittara_Honki_Dasu_Part_2
# Scrapeando reseñas desde: https://myanimelist.net/anime/45576/Mushoku_Tensei__Isekai_Ittara_Honki_Dasu_Part_2/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 6406
# Procesando Anime 96/150: Ore_dake_Level_Up_na_Ken_Season_2__Arise_from_the_Shadow
# Scrapeando reseñas desde: https://myanimelist.net/anime/58567/Ore_dake_Level_Up_na_Ken_Season_2__Arise_from_the_Shadow/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 6506
# Procesando Anime 97/150: Cyberpunk__Edgerunners
# Scrapeando reseñas desde: https://myanimelist.net/anime/42310/Cyberpunk__Edgerunners/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 6606
# Procesando Anime 98/150: Death_Note
# Scrapeando reseñas desde: https://myanimelist.net/anime/1535/Death_Note/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 6706
# Procesando Anime 99/150: Haikyuu_Second_Season
# Scrapeando reseñas desde: https://myanimelist.net/anime/28891/Haikyuu_Second_Season/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 78 reseñas. Total actual: 6784
# Procesando Anime 100/150: Bungou_Stray_Dogs_5th_Season
# Scrapeando reseñas desde: https://myanimelist.net/anime/54898/Bungou_Stray_Dogs_5th_Season/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 22 reseñas. Total actual: 6806
# Procesando Anime 101/150: Haikyuu_Movie__Gomisuteba_no_Kessen
# Scrapeando reseñas desde: https://myanimelist.net/anime/52742/Haikyuu_Movie__Gomisuteba_no_Kessen/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 40 reseñas. Total actual: 6846
# Procesando Anime 102/150: Hajime_no_Ippo__Rising
# Scrapeando reseñas desde: https://myanimelist.net/anime/19647/Hajime_no_Ippo__Rising/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 12 reseñas. Total actual: 6858
# Procesando Anime 103/150: Kenpuu_Denki_Berserk
# Scrapeando reseñas desde: https://myanimelist.net/anime/33/Kenpuu_Denki_Berserk/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 6958
# Procesando Anime 104/150: Natsume_Yuujinchou_Roku
# Scrapeando reseñas desde: https://myanimelist.net/anime/34591/Natsume_Yuujinchou_Roku/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 15 reseñas. Total actual: 6973
# Procesando Anime 105/150: Made_in_Abyss_Movie_3__Fukaki_Tamashii_no_Reimei
# Scrapeando reseñas desde: https://myanimelist.net/anime/36862/Made_in_Abyss_Movie_3__Fukaki_Tamashii_no_Reimei/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 7073
# Procesando Anime 106/150: Made_in_Abyss__Retsujitsu_no_Ougonkyou
# Scrapeando reseñas desde: https://myanimelist.net/anime/41084/Made_in_Abyss__Retsujitsu_no_Ougonkyou/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 68 reseñas. Total actual: 7141
# Procesando Anime 107/150: Tengen_Toppa_Gurren_Lagann_Movie_2__Lagann-hen
# Scrapeando reseñas desde: https://myanimelist.net/anime/4565/Tengen_Toppa_Gurren_Lagann_Movie_2__Lagann-hen/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 24 reseñas. Total actual: 7165
# Procesando Anime 108/150: Seishun_Buta_Yarou_wa_Yumemiru_Shoujo_no_Yume_wo_Minai
# Scrapeando reseñas desde: https://myanimelist.net/anime/38329/Seishun_Buta_Yarou_wa_Yumemiru_Shoujo_no_Yume_wo_Minai/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 7265
# Procesando Anime 109/150: Suzumiya_Haruhi_no_Shoushitsu
# Scrapeando reseñas desde: https://myanimelist.net/anime/7311/Suzumiya_Haruhi_no_Shoushitsu/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 7365
# Procesando Anime 110/150: Dungeon_Meshi
# Scrapeando reseñas desde: https://myanimelist.net/anime/52701/Dungeon_Meshi/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 7465
# Procesando Anime 111/150: JoJo_no_Kimyou_na_Bouken_Part_5__Ougon_no_Kaze
# Scrapeando reseñas desde: https://myanimelist.net/anime/37991/JoJo_no_Kimyou_na_Bouken_Part_5__Ougon_no_Kaze/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 7565
# Procesando Anime 112/150: Mushishi_Zoku_Shou__Suzu_no_Shizuku
# Scrapeando reseñas desde: https://myanimelist.net/anime/28957/Mushishi_Zoku_Shou__Suzu_no_Shizuku/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 9 reseñas. Total actual: 7574
# Procesando Anime 113/150: Natsume_Yuujinchou_Shichi
# Scrapeando reseñas desde: https://myanimelist.net/anime/55823/Natsume_Yuujinchou_Shichi/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 6 reseñas. Total actual: 7580
# Procesando Anime 114/150: Shin_Evangelion_Movie_||
# Scrapeando reseñas desde: https://myanimelist.net/anime/3786/Shin_Evangelion_Movie_||/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 7680
# Procesando Anime 115/150: Shingeki_no_Kyojin
# Scrapeando reseñas desde: https://myanimelist.net/anime/16498/Shingeki_no_Kyojin/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 7780
# Procesando Anime 116/150: Uma_Musume__Cinderella_Gray
# Scrapeando reseñas desde: https://myanimelist.net/anime/59636/Uma_Musume__Cinderella_Gray/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 18 reseñas. Total actual: 7798
# Procesando Anime 117/150: Nana
# Scrapeando reseñas desde: https://myanimelist.net/anime/877/Nana/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 7898
# Procesando Anime 118/150: Kizumonogatari_II__Nekketsu-hen
# Scrapeando reseñas desde: https://myanimelist.net/anime/31757/Kizumonogatari_II__Nekketsu-hen/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 39 reseñas. Total actual: 7937
# Procesando Anime 119/150: Natsume_Yuujinchou_Go
# Scrapeando reseñas desde: https://myanimelist.net/anime/32983/Natsume_Yuujinchou_Go/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 7 reseñas. Total actual: 7944
# Procesando Anime 120/150: Natsume_Yuujinchou_San
# Scrapeando reseñas desde: https://myanimelist.net/anime/10379/Natsume_Yuujinchou_San/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 15 reseñas. Total actual: 7959
# Procesando Anime 121/150: Ookami_Kodomo_no_Ame_to_Yuki
# Scrapeando reseñas desde: https://myanimelist.net/anime/12355/Ookami_Kodomo_no_Ame_to_Yuki/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 8059
# Procesando Anime 122/150: Doupo_Cangqiong__San_Nian_Zhi_Yue
# Scrapeando reseñas desde: https://myanimelist.net/anime/49701/Doupo_Cangqiong__San_Nian_Zhi_Yue/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 6 reseñas. Total actual: 8065
# Procesando Anime 123/150: Haikyuu_To_the_Top_Part_2
# Scrapeando reseñas desde: https://myanimelist.net/anime/40776/Haikyuu_To_the_Top_Part_2/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 55 reseñas. Total actual: 8120
# Procesando Anime 124/150: Shinseiki_Evangelion_Movie__Air_Magokoro_wo_Kimi_ni
# Scrapeando reseñas desde: https://myanimelist.net/anime/32/Shinseiki_Evangelion_Movie__Air_Magokoro_wo_Kimi_ni/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 8220
# Procesando Anime 125/150: Shouwa_Genroku_Rakugo_Shinjuu
# Scrapeando reseñas desde: https://myanimelist.net/anime/28735/Shouwa_Genroku_Rakugo_Shinjuu/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 84 reseñas. Total actual: 8304
# Procesando Anime 126/150: Slam_Dunk
# Scrapeando reseñas desde: https://myanimelist.net/anime/170/Slam_Dunk/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 46 reseñas. Total actual: 8350
# Procesando Anime 127/150: Steins_Gate_0
# Scrapeando reseñas desde: https://myanimelist.net/anime/30484/Steins_Gate_0/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 8450
# Procesando Anime 128/150: Yojouhan_Shinwa_Taikei
# Scrapeando reseñas desde: https://myanimelist.net/anime/7785/Yojouhan_Shinwa_Taikei/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 8550
# Procesando Anime 129/150: Oshi_no_Ko
# Scrapeando reseñas desde: https://myanimelist.net/anime/52034/Oshi_no_Ko/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 8650
# Procesando Anime 130/150: Kimetsu_no_Yaiba_Movie__Mugen_Ressha-hen
# Scrapeando reseñas desde: https://myanimelist.net/anime/40456/Kimetsu_no_Yaiba_Movie__Mugen_Ressha-hen/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 8750
# Procesando Anime 131/150: Kimi_no_Suizou_wo_Tabetai
# Scrapeando reseñas desde: https://myanimelist.net/anime/36098/Kimi_no_Suizou_wo_Tabetai/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 8850
# Procesando Anime 132/150: Perfect_Blue
# Scrapeando reseñas desde: https://myanimelist.net/anime/437/Perfect_Blue/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 8950
# Procesando Anime 133/150: Oshi_no_Ko_2nd_Season
# Scrapeando reseñas desde: https://myanimelist.net/anime/55791/Oshi_no_Ko_2nd_Season/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 61 reseñas. Total actual: 9011
# Procesando Anime 134/150: Fate_Zero_2nd_Season
# Scrapeando reseñas desde: https://myanimelist.net/anime/11741/Fate_Zero_2nd_Season/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 9111
# Procesando Anime 135/150: Fruits_Basket_2nd_Season
# Scrapeando reseñas desde: https://myanimelist.net/anime/40417/Fruits_Basket_2nd_Season/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 43 reseñas. Total actual: 9154
# Procesando Anime 136/150: Hotaru_no_Haka
# Scrapeando reseñas desde: https://myanimelist.net/anime/578/Hotaru_no_Haka/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 9254
# Procesando Anime 137/150: Jujutsu_Kaisen
# Scrapeando reseñas desde: https://myanimelist.net/anime/40748/Jujutsu_Kaisen/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 9354
# Procesando Anime 138/150: Shingeki_no_Kyojin_Season_2
# Scrapeando reseñas desde: https://myanimelist.net/anime/25777/Shingeki_no_Kyojin_Season_2/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 9454
# Procesando Anime 139/150: Zoku_Natsume_Yuujinchou
# Scrapeando reseñas desde: https://myanimelist.net/anime/5300/Zoku_Natsume_Yuujinchou/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 19 reseñas. Total actual: 9473
# Procesando Anime 140/150: Samurai_Champloo
# Scrapeando reseñas desde: https://myanimelist.net/anime/205/Samurai_Champloo/reviews?sort=suggested
# Añadidas 100 reseñas. Total actual: 9573
# Procesando Anime 141/150: Bakuman_3rd_Season
# Scrapeando reseñas desde: https://myanimelist.net/anime/12365/Bakuman_3rd_Season/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 44 reseñas. Total actual: 9617
# Procesando Anime 142/150: Dr_Stone__Science_Future_Part_2
# Scrapeando reseñas desde: https://myanimelist.net/anime/61322/Dr_Stone__Science_Future_Part_2/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 15 reseñas. Total actual: 9632
# Procesando Anime 143/150: Gintama_Movie_1__Shinyaku_Benizakura-hen
# Scrapeando reseñas desde: https://myanimelist.net/anime/7472/Gintama_Movie_1__Shinyaku_Benizakura-hen/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 22 reseñas. Total actual: 9654
# Procesando Anime 144/150: Mushishi__Hihamukage
# Scrapeando reseñas desde: https://myanimelist.net/anime/21329/Mushishi__Hihamukage/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 15 reseñas. Total actual: 9669
# Procesando Anime 145/150: JoJo_no_Kimyou_na_Bouken_Part_6__Stone_Ocean_Part_3
# Scrapeando reseñas desde: https://myanimelist.net/anime/53273/JoJo_no_Kimyou_na_Bouken_Part_6__Stone_Ocean_Part_3/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 39 reseñas. Total actual: 9708
# Procesando Anime 146/150: Kara_no_Kyoukai_Movie_5__Mujun_Rasen
# Scrapeando reseñas desde: https://myanimelist.net/anime/4282/Kara_no_Kyoukai_Movie_5__Mujun_Rasen/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 31 reseñas. Total actual: 9739
# Procesando Anime 147/150: Koukaku_Kidoutai__Stand_Alone_Complex_2nd_GIG
# Scrapeando reseñas desde: https://myanimelist.net/anime/801/Koukaku_Kidoutai__Stand_Alone_Complex_2nd_GIG/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 25 reseñas. Total actual: 9764
# Procesando Anime 148/150: Nezha_Zhi_Mo_Tong_Nao_Hai
# Scrapeando reseñas desde: https://myanimelist.net/anime/60544/Nezha_Zhi_Mo_Tong_Nao_Hai/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 4 reseñas. Total actual: 9768
# Procesando Anime 149/150: Gintama_Porori-hen
# Scrapeando reseñas desde: https://myanimelist.net/anime/35843/Gintama_Porori-hen/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 18 reseñas. Total actual: 9786
# Procesando Anime 150/150: Grand_Blue_Season_2
# Scrapeando reseñas desde: https://myanimelist.net/anime/59986/Grand_Blue_Season_2/reviews?sort=suggested
# Página duplicada detectada. Deteniendo búsqueda.
# Añadidas 17 reseñas. Total actual: 9803
# Guardando 9803 reseñas totales en 'reviews_complete.csv'.
# Proceso de scraping masivo completado
